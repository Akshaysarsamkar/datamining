# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshaysarsamkar/datamining/blob/main/multipleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

# %%
df = files.upload()
# Out:
#      <input type="file" id="files-f92d6cd0-bd45-4d45-b7a5-8cb5a63f2e76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f92d6cd0-bd45-4d45-b7a5-8cb5a63f2e76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("insurance.csv")
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df["sex"] = df["sex"].astype('category')
df["sex"] = df["sex"].cat.codes

df["region"] = df["region"].astype('category')
df["region"] = df["region"].cat.codes

df["smoker"] = df["smoker"].astype('category')
df["smoker"] = df["smoker"].cat.codes

# %%
df
# Out:
#       age  sex   bmi  children  smoker  region  expenses
# 0      19    0  27.9         0       1       3  16884.92
# 1      18    1  33.8         1       0       2   1725.55
# 2      28    1  33.0         3       0       2   4449.46
# 3      33    1  22.7         0       0       1  21984.47
# 4      32    1  28.9         0       0       1   3866.86
# ...   ...  ...   ...       ...     ...     ...       ...
# 1333   50    1  31.0         3       0       1  10600.55
# 1334   18    0  31.9         0       0       0   2205.98
# 1335   18    0  36.9         0       0       2   1629.83
# 1336   21    0  25.8         0       0       3   2007.95
# 1337   61    0  29.1         0       1       1  29141.36
#
# [1338 rows x 7 columns]

# %%
x = df.iloc[:,0:6].values
y = df.iloc[:, -1].values
x
# Out:
# array([[19. ,  0. , 27.9,  0. ,  1. ,  3. ],
#        [18. ,  1. , 33.8,  1. ,  0. ,  2. ],
#        [28. ,  1. , 33. ,  3. ,  0. ,  2. ],
#        ...,
#        [18. ,  0. , 36.9,  0. ,  0. ,  2. ],
#        [21. ,  0. , 25.8,  0. ,  0. ,  3. ],
#        [61. ,  0. , 29.1,  0. ,  1. ,  1. ]])

# %%
y
# Out:
# array([16884.92,  1725.55,  4449.46, ...,  1629.83,  2007.95, 29141.36])

# %%
from sklearn. model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
m = LinearRegression ()

# %%
m.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
c = m.intercept_
c
# Out:
# -12185.073992583182

# %%
c1 = m.coef_
c1
# Out:
# array([  256.37363193,  -153.19326287,   337.54211764,   582.78905738,
#        23889.73540956,  -309.69037635])

# %%
y_pred = m.predict(x_train)
y_pred
# Out:
# array([16097.00733107,  5522.45851786,  6774.89116151, ...,
#        17736.02398418,  7696.78734186,  1307.00907617])

# %%
import matplotlib.pyplot as plt
plt.scatter(y_train, y_pred)

# %%
from sklearn.metrics import r2_score
r2_score(y_train, y_pred)
# Out:
# 0.7570040632485915
